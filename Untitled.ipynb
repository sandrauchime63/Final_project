# %%
pip install matplotlib
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/Users/Sandras/Desktop/Python/FLEXISAF/Final_project/langchain_env/lib/python3.10/site-packages)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in ./langchain_env/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in ./langchain_env/lib/python3.10/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./langchain_env/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./langchain_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./langchain_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 4.7/8.2 MB 25.4 kB/s eta 0:02:19
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (4.7 MB/8.2 MB, attempt 1)
# Resuming download matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl (4.7 MB/8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 65.9 kB/s  0:01:39m0:00:0200:07
# Using cached contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp310-cp310-macosx_10_9_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 81.3 kB/s  0:00:29 eta 0:00:05m
# Downloading kiwisolver-1.5.0-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# WARNING: Ignoring invalid distribution -ransformers (/Users/Sandras/Desktop/Python/FLEXISAF/Final_project/langchain_env/lib/python3.10/site-packages)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# WARNING: Ignoring invalid distribution -ransformers (/Users/Sandras/Desktop/Python/FLEXISAF/Final_project/langchain_env/lib/python3.10/site-packages)
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from sklearn.preprocessing import PolynomialFeatures
#       4 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'matplotlib'
